# %%
import fiona
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
from descartes import PolygonPatch

# %%
from shapely.geometry import MultiPolygon, shape
# Out:
# Failed `CDLL(/Library/Frameworks/GEOS.framework/Versions/Current/GEOS)`
# WARNING:shapely.geos:Failed `CDLL(/Library/Frameworks/GEOS.framework/Versions/Current/GEOS)`
# Failed `CDLL(/opt/local/lib/libgeos_c.dylib)`
# WARNING:shapely.geos:Failed `CDLL(/opt/local/lib/libgeos_c.dylib)`
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/anaconda/lib/python3.4/site-packages/shapely/geos.py in <module>()
#      81         try:
# ---> 82             _lgeos = CDLL(dll_path, mode=(DEFAULT_MODE | 16))
#      83         except OSError:
#
# /usr/local/anaconda/lib/python3.4/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     350         if handle is None:
# --> 351             self._handle = _dlopen(self._name, mode)
#     352         else:
#
# OSError: image not already loaded
#
# ...

# %%
# %matplotlib nbagg

# %%
fig, ax = plt.subplots()
with fiona.open('R02_11_WGS84/R02_WGS84.shp', 'r') as features:
    mp = MultiPolygon([shape(pol['geometry']) for pol in fiona.open('R02_11_WGS84/R02_WGS84.shp')])
    minx, miny, maxx, maxy = mp.bounds
    w, h = maxx - minx, maxy - miny
    ax.set_xlim(minx - 0.2 * w, maxx + 0.2 * w)
    ax.set_ylim(miny - 0.2 * h, maxy + 0.2 * h)
    ax.set_aspect(1)
    patches = []
    for idx, p in enumerate(mp):
        patches.append(PolygonPatch(p, fc="gray", ec='black', alpha=1, zorder=1))
    ax.add_collection(PatchCollection(patches, match_original=True))
    plt.show()
# Out:
# <img src="data:image/png;base64,...">
